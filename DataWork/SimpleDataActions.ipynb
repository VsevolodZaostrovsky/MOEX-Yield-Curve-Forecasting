# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
main_df_train = pd.read_csv("Data/RussianCurve.csv")

# %%
main_df_test = main_df_train.reset_index()

# %%
main_df_train = main_df_train.drop(['index'], axis=1)

# %%
main_df_train.to_csv("Data/main_df_train.csv")

# %%
main_df = main_df[::-1]

# %%
main_df = main_df.reset_index()

# %%
main_df = main_df.drop(['index'], axis=1)

# %%
main_df
# Out:
#             date   0.25    0.5   0.75    1.0    2.0    3.0    5.0    7.0  \
# 0     2008-01-09   5.69   5.76   5.83   5.88   6.03   6.13   6.26   6.37
# 1     2008-01-10   5.53   5.61   5.69   5.76   5.95   6.06   6.21   6.32
# 2     2008-01-11   5.17   5.29   5.42   5.53   5.83   5.98   6.15   6.26
# 3     2008-01-14   5.13   5.28   5.43   5.56   5.89   6.02   6.16   6.26
# 4     2008-01-15   5.31   5.45   5.59   5.70   5.99   6.11   6.25   6.34
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1829  2014-12-24  15.45  15.53  15.56  15.56  15.45  15.38  14.98  14.27
# 1830  2014-12-25  14.86  14.92  14.96  15.02  15.27  15.39  14.98  14.18
# 1831  2014-12-26  14.47  14.52  14.57  14.64  14.99  15.20  14.88  14.12
# 1832  2014-12-29  13.57  13.63  13.79  14.04  15.16  15.55  15.20  14.38
# 1833  2014-12-30  12.74  13.10  13.50  13.90  15.14  15.51  15.13  14.31
#
#        10.0   15.0   20.0   30.0
# 0      6.50   6.68   6.81   6.97
# ...

# %%
main_df = main_df.reset_index()
main_df = main_df.drop(['index'], axis=1)

# %%
main_df.to_csv('FedYeildCurve.csv')

# %%
mdf = pd.read_csv('Data/FedYeildCurve.csv')

# %%
mdf = mdf.drop(['0.75'], axis=1)

# %%
mdf = mdf.drop(['Unnamed: 0'], axis=1)
mdf.head(-5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/vsevolod/GitHubRepos/FinancialEconometrics/DataWork/SimpleDataActions.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/home/vsevolod/GitHubRepos/FinancialEconometrics/DataWork/SimpleDataActions.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> mdf = mdf.drop(['Unnamed: 0'], axis=1)
#       <a href='vscode-notebook-cell:/home/vsevolod/GitHubRepos/FinancialEconometrics/DataWork/SimpleDataActions.ipynb#X23sZmlsZQ%3D%3D?line=1'>2</a> mdf.head(-5)
#       <a href='vscode-notebook-cell:/home/vsevolod/GitHubRepos/FinancialEconometrics/DataWork/SimpleDataActions.ipynb#X23sZmlsZQ%3D%3D?line=2'>3</a> main_df.to_csv('FedYeildCurve.csv')
#
# File /usr/lib64/python3.11/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
# ...

# %%
main_df = pd.read_csv('Data/RussianCurve.csv')

# %%
main_df['date'] = pd.to_datetime(main_df['date'])

# %%
main_df = main_df[::-1]

# %%
main_df = main_df.reset_index()

# %%
main_df = main_df.drop(['30.0'], axis=1)
main_df.head(-5)
# Out:
#            date   0.25    0.5    1.0    2.0    3.0    5.0    7.0   10.0
# 0    2008-01-09   5.69   5.76   5.88   6.03   6.13   6.26   6.37   6.50
# 1    2008-01-10   5.53   5.61   5.76   5.95   6.06   6.21   6.32   6.46
# 2    2008-01-11   5.17   5.29   5.53   5.83   5.98   6.15   6.26   6.40
# 3    2008-01-14   5.13   5.28   5.56   5.89   6.02   6.16   6.26   6.39
# 4    2008-01-15   5.31   5.45   5.70   5.99   6.11   6.25   6.34   6.46
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1824 2014-12-17  13.51  14.06  14.90  15.75  15.87  15.01  13.89  12.72
# 1825 2014-12-18  14.44  14.78  15.27  15.75  15.79  15.16  14.19  12.87
# 1826 2014-12-19  15.30  15.46  15.64  15.86  15.87  15.19  14.20  12.95
# 1827 2014-12-22  14.91  14.96  15.02  15.20  15.20  14.58  13.68  12.47
# 1828 2014-12-23  15.28  15.34  15.39  15.44  15.36  14.76  13.91  12.69
#
# [1829 rows x 9 columns]

# %%
edf = main_df[main_df['date'].dt.day == 1]

# %%
edf.head(-5)
# Out:
#            date   0.25    0.5    1.0    2.0    3.0    5.0    7.0   10.0
# 17   2008-02-01   5.13   5.27   5.51   5.81   5.97   6.18   6.31   6.47
# 56   2008-04-01   5.67   5.75   5.88   6.04   6.21   6.48   6.67   6.88
# 118  2008-07-01   5.41   5.53   5.73   6.05   6.26   6.52   6.68   6.88
# 141  2008-08-01   5.41   5.51   5.72   6.11   6.42   6.83   7.08   7.31
# 162  2008-09-01   6.10   6.23   6.47   6.88   7.17   7.61   7.93   8.30
# 184  2008-10-01   6.60   6.68   6.86   7.17   7.36   7.56   7.72   8.06
# 207  2008-11-01   8.73   8.79   8.87   8.86   8.74   8.51   8.39   8.43
# 226  2008-12-01  10.62  10.67  10.69  10.43  10.01   9.28   8.81   8.48
# 304  2009-04-01   9.77  10.04  10.56  11.24  11.47  11.56  11.62  11.88
# 345  2009-06-01   8.03   8.78   9.95  11.33  11.88  12.12  12.06  11.96
# 366  2009-07-01   8.13   9.18  10.56  11.71  11.92  11.77  11.65  11.63
# 410  2009-09-01   8.73   9.34  10.27  11.36  11.88  12.17  12.13  11.98
# ...

# %%
edf.to_csv('Data/FedYeildCurve1DayMonth.csv')

# %%
edf = pd.read_csv('Data/FedYeildCurve1DayMonth.csv')

# %%
edf = edf.reset_index()
edf = edf.drop(['index'], axis=1)

# %%
edf = edf.drop(['Unnamed: 0'], axis=1)

# %%
edf.to_csv('Data/FedYeildCurve1DayMonth.csv')
