# %%
import numpy as np
import pandas as pd 
from scipy.optimize import least_squares
from sklearn.model_selection import train_test_split 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data/General_ds.csv")
print(len(df))
# Out:
# 5308

# %%
plt.plot(df["beta0"])

# %%
df = df.loc[df["beta0"] > 600]
df = df.loc[df["beta0"] < 1500]
df["beta0"].hist(bins=100)
print(len(df))
# Out:
# 4986

# %%
df = df.loc[df["beta1"] > -800]
df = df.loc[df["beta1"] < 600]
df["beta1"].hist(bins=100)
print(len(df))
# Out:
# 4990

# %%
df = df.loc[df["beta2"] < 1000]
df = df.loc[df["beta2"] > -1000]
df["beta2"].hist(bins=100)
print(len(df))
# Out:
# 4999

# %%
df = df.loc[df["tau"] < 14]
df["tau"].hist(bins=100)
print(len(df))
# Out:
# 4926

# %%
df.to_csv("General_ds_cleaned.csv")
