# %%
library(forecast)
library(tseries)
library(vars)
library(openxlsx)
library(urca)
library(ggplot2)
library(midasr)
library(strucchange)
library(quantmod)
library(rusquant)
library(dplyr)
library(tsbox)
library(MSwM)
library(readr)

# %%
General_ds_cleaned <- read_csv("~/GitHubRepos/FinancialEconometrics/DataWork/Data/General_ds_cleaned.csv")
# Out:
# New names:
# • `` -> `...1`
# Warning message:
# “One or more parsing issues, call `problems()` on your data frame for details,
# e.g.:
#   dat <- vroom(...)
#   problems(dat)”
# Rows: 4926 Columns: 23
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl  (22): ...1, Unnamed: 0, Y025, 0.5, 0.75, 1.0, 2.0, 3.0, 5.0, 7.0, 10.0,...
# date  (1): date
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
dUse <- data.frame(beta0 = diff(General_ds_cleaned$beta0),
                     beta1 = diff(General_ds_cleaned$beta1),
                     beta2 = diff(General_ds_cleaned$beta2))

var <- VAR(dUse, p = 1)

irf(var)
plot(irf(var))
# Out:
# Impulse response coefficients
# $beta0
#               beta0         beta1         beta2
#  [1,]  4.430963e+01 -0.3074125307 -31.083498904
#  [2,] -1.350627e+01 -0.5362135797  10.301921281
#  [3,]  4.132924e+00  0.3560347095  -3.494349117
#  [4,] -1.269521e+00 -0.1683879856   1.211755629
#  [5,]  3.914396e-01  0.0702807124  -0.428809754
#  [6,] -1.211503e-01 -0.0275442932   0.154486481
#  [7,]  3.763794e-02  0.0104147465  -0.056515711
#  [8,] -1.173803e-02 -0.0038545072   0.020940507
#  [9,]  3.675197e-03  0.0014086534  -0.007840009
# [10,] -1.155468e-03 -0.0005112955   0.002959764
# [11,]  3.648662e-04  0.0001850665  -0.001124736
#
# $beta1
#               beta0         beta1        beta2
#  [1,]  0.0000000000  5.285484e+01  2.199417609
#  [2,] -1.3687764128 -1.555879e+01  2.186360302
#  [3,]  0.8197153250  4.615098e+00 -1.682718800
#  [4,] -0.3690547351 -1.381040e+00  0.881520664
#  [5,]  0.1480780026  4.174617e-01 -0.404554807
#  [6,] -0.0558587300 -1.276509e-01  0.174035481
# ...
